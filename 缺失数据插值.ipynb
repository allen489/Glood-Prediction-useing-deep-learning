# %%
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader, TensorDataset

# 导入自己的数据
df = pd.read_csv(r'C:\Users\admin\Desktop\Filtered_Data2.csv', encoding='utf-8', header=None)
df.columns = ['time','id','gl']

# %%
ID = df['id'].value_counts().index
pd.set_option('display.max_rows',100)
print(ID)
# Out:
# Index([263,  77, 193, 277, 229, 251, 245, 155, 111, 228,
#        ...
#        264, 167, 186, 249, 162,  39,  52, 266, 223, 289],
#       dtype='int64', name='id', length=226)

# %%
all_data = []
for i in ID:
    #获取数据
    print("开始获取id为{}的被试的数据：---------------------------------".format(i))
    data = df[df['id']== i].copy()

    #将time列设成date数据类型
    data['time'] = pd.to_datetime(data['time'])
    
    #按照时间排序
    data = data.sort_values(by='time') 
    
    #提取月为单独的一列
    data['month'] = data['time'].dt.month
    
    #提取日为单独的一列
    data['day'] = data['time'].dt.day
    
    #提取小时为单独的一列
    data['hour'] = data['time'].dt.hour
    
    #提取分钟为单独的一列
    data['minute'] = data['time'].dt.minute
    
    # 提取周几（0表示星期一，1表示星期二，依此类推）
    data['weekday'] = data['time'].dt.dayofweek
    
    #以time为索引
    data = data.set_index('time')
                      
    data = data[['id', 'month','day','hour','minute','weekday','gl']].astype(np.float32)  # 修改数据类型
    all_data.append(data)
# Out:
# 开始获取id为263的被试的数据：---------------------------------
# 开始获取id为77的被试的数据：---------------------------------
# 开始获取id为193的被试的数据：---------------------------------
# 开始获取id为277的被试的数据：---------------------------------
# 开始获取id为229的被试的数据：---------------------------------
# 开始获取id为251的被试的数据：---------------------------------
# 开始获取id为245的被试的数据：---------------------------------
# 开始获取id为155的被试的数据：---------------------------------
# 开始获取id为111的被试的数据：---------------------------------
# 开始获取id为228的被试的数据：---------------------------------
# 开始获取id为130的被试的数据：---------------------------------
# 开始获取id为232的被试的数据：---------------------------------
# 开始获取id为68的被试的数据：---------------------------------
# 开始获取id为23的被试的数据：---------------------------------
# 开始获取id为7的被试的数据：---------------------------------
# 开始获取id为164的被试的数据：---------------------------------
# 开始获取id为70的被试的数据：---------------------------------
# 开始获取id为102的被试的数据：---------------------------------
# 开始获取id为227的被试的数据：---------------------------------
# 开始获取id为95的被试的数据：---------------------------------
# 开始获取id为243的被试的数据：---------------------------------
# 开始获取id为105的被试的数据：---------------------------------
# 开始获取id为271的被试的数据：---------------------------------
# 开始获取id为250的被试的数据：---------------------------------
# 开始获取id为101的被试的数据：---------------------------------
# 开始获取id为137的被试的数据：---------------------------------
# 开始获取id为220的被试的数据：---------------------------------
# 开始获取id为67的被试的数据：---------------------------------
# 开始获取id为214的被试的数据：---------------------------------
# 开始获取id为139的被试的数据：---------------------------------
# 开始获取id为269的被试的数据：---------------------------------
# 开始获取id为198的被试的数据：---------------------------------
# 开始获取id为187的被试的数据：---------------------------------
# 开始获取id为54的被试的数据：---------------------------------
# 开始获取id为253的被试的数据：---------------------------------
# 开始获取id为205的被试的数据：---------------------------------
# 开始获取id为123的被试的数据：---------------------------------
# 开始获取id为17的被试的数据：---------------------------------
# 开始获取id为76的被试的数据：---------------------------------
# 开始获取id为138的被试的数据：---------------------------------
# 开始获取id为166的被试的数据：---------------------------------
# 开始获取id为109的被试的数据：---------------------------------
# 开始获取id为135的被试的数据：---------------------------------
# 开始获取id为65的被试的数据：---------------------------------
# 开始获取id为146的被试的数据：---------------------------------
# 开始获取id为127的被试的数据：---------------------------------
# 开始获取id为136的被试的数据：---------------------------------
# 开始获取id为3的被试的数据：---------------------------------
# 开始获取id为9的被试的数据：---------------------------------
# 开始获取id为203的被试的数据：---------------------------------
# 开始获取id为81的被试的数据：---------------------------------
# 开始获取id为116的被试的数据：---------------------------------
# 开始获取id为240的被试的数据：---------------------------------
# 开始获取id为74的被试的数据：---------------------------------
# 开始获取id为184的被试的数据：---------------------------------
# 开始获取id为274的被试的数据：---------------------------------
# 开始获取id为258的被试的数据：---------------------------------
# 开始获取id为33的被试的数据：---------------------------------
# 开始获取id为278的被试的数据：---------------------------------
# 开始获取id为129的被试的数据：---------------------------------
# 开始获取id为218的被试的数据：---------------------------------
# 开始获取id为134的被试的数据：---------------------------------
# 开始获取id为247的被试的数据：---------------------------------
# 开始获取id为283的被试的数据：---------------------------------
# 开始获取id为61的被试的数据：---------------------------------
# 开始获取id为32的被试的数据：---------------------------------
# 开始获取id为47的被试的数据：---------------------------------
# 开始获取id为53的被试的数据：---------------------------------
# 开始获取id为14的被试的数据：---------------------------------
# 开始获取id为124的被试的数据：---------------------------------
# 开始获取id为188的被试的数据：---------------------------------
# 开始获取id为113的被试的数据：---------------------------------
# 开始获取id为234的被试的数据：---------------------------------
# 开始获取id为175的被试的数据：---------------------------------
# 开始获取id为265的被试的数据：---------------------------------
# 开始获取id为58的被试的数据：---------------------------------
# 开始获取id为156的被试的数据：---------------------------------
# 开始获取id为106的被试的数据：---------------------------------
# 开始获取id为60的被试的数据：---------------------------------
# 开始获取id为71的被试的数据：---------------------------------
# 开始获取id为201的被试的数据：---------------------------------
# 开始获取id为189的被试的数据：---------------------------------
# 开始获取id为273的被试的数据：---------------------------------
# 开始获取id为185的被试的数据：---------------------------------
# 开始获取id为158的被试的数据：---------------------------------
# 开始获取id为79的被试的数据：---------------------------------
# 开始获取id为165的被试的数据：---------------------------------
# 开始获取id为26的被试的数据：---------------------------------
# 开始获取id为22的被试的数据：---------------------------------
# 开始获取id为281的被试的数据：---------------------------------
# 开始获取id为16的被试的数据：---------------------------------
# 开始获取id为216的被试的数据：---------------------------------
# 开始获取id为119的被试的数据：---------------------------------
# 开始获取id为48的被试的数据：---------------------------------
# 开始获取id为206的被试的数据：---------------------------------
# 开始获取id为27的被试的数据：---------------------------------
# 开始获取id为31的被试的数据：---------------------------------
# 开始获取id为37的被试的数据：---------------------------------
# 开始获取id为231的被试的数据：---------------------------------
# 开始获取id为276的被试的数据：---------------------------------
# 开始获取id为2的被试的数据：---------------------------------
# 开始获取id为64的被试的数据：---------------------------------
# 开始获取id为18的被试的数据：---------------------------------
# 开始获取id为236的被试的数据：---------------------------------
# 开始获取id为219的被试的数据：---------------------------------
# 开始获取id为267的被试的数据：---------------------------------
# 开始获取id为103的被试的数据：---------------------------------
# 开始获取id为36的被试的数据：---------------------------------
# 开始获取id为224的被试的数据：---------------------------------
# 开始获取id为215的被试的数据：---------------------------------
# 开始获取id为168的被试的数据：---------------------------------
# 开始获取id为10的被试的数据：---------------------------------
# 开始获取id为272的被试的数据：---------------------------------
# 开始获取id为233的被试的数据：---------------------------------
# 开始获取id为87的被试的数据：---------------------------------
# 开始获取id为288的被试的数据：---------------------------------
# 开始获取id为241的被试的数据：---------------------------------
# 开始获取id为90的被试的数据：---------------------------------
# 开始获取id为197的被试的数据：---------------------------------
# 开始获取id为38的被试的数据：---------------------------------
# 开始获取id为176的被试的数据：---------------------------------
# 开始获取id为143的被试的数据：---------------------------------
# 开始获取id为213的被试的数据：---------------------------------
# 开始获取id为179的被试的数据：---------------------------------
# 开始获取id为275的被试的数据：---------------------------------
# 开始获取id为29的被试的数据：---------------------------------
# 开始获取id为172的被试的数据：---------------------------------
# 开始获取id为163的被试的数据：---------------------------------
# 开始获取id为173的被试的数据：---------------------------------
# 开始获取id为170的被试的数据：---------------------------------
# 开始获取id为287的被试的数据：---------------------------------
# 开始获取id为30的被试的数据：---------------------------------
# 开始获取id为97的被试的数据：---------------------------------
# 开始获取id为190的被试的数据：---------------------------------
# 开始获取id为46的被试的数据：---------------------------------
# 开始获取id为183的被试的数据：---------------------------------
# 开始获取id为285的被试的数据：---------------------------------
# 开始获取id为160的被试的数据：---------------------------------
# 开始获取id为35的被试的数据：---------------------------------
# 开始获取id为121的被试的数据：---------------------------------
# 开始获取id为24的被试的数据：---------------------------------
# 开始获取id为93的被试的数据：---------------------------------
# 开始获取id为210的被试的数据：---------------------------------
# 开始获取id为40的被试的数据：---------------------------------
# 开始获取id为149的被试的数据：---------------------------------
# 开始获取id为108的被试的数据：---------------------------------
# 开始获取id为15的被试的数据：---------------------------------
# 开始获取id为290的被试的数据：---------------------------------
# 开始获取id为239的被试的数据：---------------------------------
# 开始获取id为132的被试的数据：---------------------------------
# 开始获取id为222的被试的数据：---------------------------------
# 开始获取id为292的被试的数据：---------------------------------
# 开始获取id为49的被试的数据：---------------------------------
# 开始获取id为147的被试的数据：---------------------------------
# 开始获取id为140的被试的数据：---------------------------------
# 开始获取id为174的被试的数据：---------------------------------
# 开始获取id为43的被试的数据：---------------------------------
# 开始获取id为110的被试的数据：---------------------------------
# 开始获取id为72的被试的数据：---------------------------------
# 开始获取id为82的被试的数据：---------------------------------
# 开始获取id为211的被试的数据：---------------------------------
# 开始获取id为152的被试的数据：---------------------------------
# 开始获取id为260的被试的数据：---------------------------------
# 开始获取id为217的被试的数据：---------------------------------
# 开始获取id为141的被试的数据：---------------------------------
# 开始获取id为41的被试的数据：---------------------------------
# 开始获取id为50的被试的数据：---------------------------------
# 开始获取id为291的被试的数据：---------------------------------
# 开始获取id为200的被试的数据：---------------------------------
# 开始获取id为293的被试的数据：---------------------------------
# 开始获取id为57的被试的数据：---------------------------------
# 开始获取id为98的被试的数据：---------------------------------
# 开始获取id为257的被试的数据：---------------------------------
# 开始获取id为11的被试的数据：---------------------------------
# 开始获取id为96的被试的数据：---------------------------------
# 开始获取id为246的被试的数据：---------------------------------
# 开始获取id为131的被试的数据：---------------------------------
# 开始获取id为115的被试的数据：---------------------------------
# 开始获取id为148的被试的数据：---------------------------------
# 开始获取id为145的被试的数据：---------------------------------
# 开始获取id为89的被试的数据：---------------------------------
# 开始获取id为19的被试的数据：---------------------------------
# 开始获取id为235的被试的数据：---------------------------------
# 开始获取id为171的被试的数据：---------------------------------
# 开始获取id为204的被试的数据：---------------------------------
# 开始获取id为20的被试的数据：---------------------------------
# 开始获取id为169的被试的数据：---------------------------------
# 开始获取id为45的被试的数据：---------------------------------
# 开始获取id为181的被试的数据：---------------------------------
# 开始获取id为42的被试的数据：---------------------------------
# 开始获取id为62的被试的数据：---------------------------------
# 开始获取id为256的被试的数据：---------------------------------
# 开始获取id为254的被试的数据：---------------------------------
# 开始获取id为226的被试的数据：---------------------------------
# 开始获取id为280的被试的数据：---------------------------------
# 开始获取id为91的被试的数据：---------------------------------
# 开始获取id为157的被试的数据：---------------------------------
# 开始获取id为221的被试的数据：---------------------------------
# 开始获取id为248的被试的数据：---------------------------------
# 开始获取id为78的被试的数据：---------------------------------
# 开始获取id为112的被试的数据：---------------------------------
# 开始获取id为73的被试的数据：---------------------------------
# 开始获取id为86的被试的数据：---------------------------------
# 开始获取id为244的被试的数据：---------------------------------
# 开始获取id为252的被试的数据：---------------------------------
# 开始获取id为5的被试的数据：---------------------------------
# 开始获取id为284的被试的数据：---------------------------------
# 开始获取id为8的被试的数据：---------------------------------
# 开始获取id为21的被试的数据：---------------------------------
# 开始获取id为118的被试的数据：---------------------------------
# 开始获取id为55的被试的数据：---------------------------------
# 开始获取id为69的被试的数据：---------------------------------
# 开始获取id为177的被试的数据：---------------------------------
# 开始获取id为80的被试的数据：---------------------------------
# 开始获取id为209的被试的数据：---------------------------------
# 开始获取id为128的被试的数据：---------------------------------
# 开始获取id为264的被试的数据：---------------------------------
# 开始获取id为167的被试的数据：---------------------------------
# 开始获取id为186的被试的数据：---------------------------------
# 开始获取id为249的被试的数据：---------------------------------
# 开始获取id为162的被试的数据：---------------------------------
# 开始获取id为39的被试的数据：---------------------------------
# 开始获取id为52的被试的数据：---------------------------------
# 开始获取id为266的被试的数据：---------------------------------
# 开始获取id为223的被试的数据：---------------------------------
# 开始获取id为289的被试的数据：---------------------------------

# %%
all_data = pd.concat(all_data, axis=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))  
sel_col = ['id','month','day','hour','minute','weekday','gl']
for col in sel_col:                           
    all_data[col] = scaler.fit_transform(all_data[col].values.reshape(-1,1))

# %%
all_data['gl'] = all_data['gl'].replace(0, np.nan)

# %%
mask = np.isnan(all_data)
mask = mask.to_numpy()
all_data['gl'] = np.nan_to_num(all_data['gl'])
np_data = all_data.values

# %%
import torch
tensor_data = torch.from_numpy(np_data.reshape(-1,7)).to(torch.float32)
mask = torch.tensor(mask, dtype=torch.float32).view(-1,7)

# %%
from torch.utils.data import DataLoader, TensorDataset
trainSet = TensorDataset(tensor_data, mask)
batch_size = 64
trainLoader = DataLoader(dataset=trainSet, batch_size=batch_size, shuffle=True, drop_last=False)

# %%
for a,b in trainLoader:
    print(a.shape)
    print(b.shape)
    break
# Out:
# torch.Size([64, 7])
# torch.Size([64, 7])

# %%
# GAIN模型 
import torch.nn as nn
class Generator(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Generator, self).__init__()
        self.fc1 = nn.Linear(input_dim * 2, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, input_dim)

    def forward(self, input_data):
        x = torch.relu(self.fc1(input_data))
        x = torch.relu(self.fc2(x))
        generated_data = torch.sigmoid(self.fc3(x))
        return generated_data

class Discriminator(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, input_dim)

    def forward(self, input_data):
        x = torch.relu(self.fc1(input_data))
        x = torch.relu(self.fc2(x))
        validity = torch.sigmoid(self.fc3(x))
        return validity

# %%
import torch.optim as optim
# 模型参数
input_dim = 7  # 输入维度
hidden_dim = 64  # 隐层维度

# 创建生成器和判别器实例
generator = Generator(input_dim, hidden_dim)

discriminator = Discriminator(input_dim, hidden_dim)

# 设置优化器
gen_optimizer = optim.Adam(generator.parameters(), lr=0.001)
dis_optimizer = optim.Adam(discriminator.parameters(), lr=0.001)

# %%
# 定义损失函数（均方误差损失）
loss_function = nn.BCELoss()

# 创建均方误差损失函数
mse_loss = nn.MSELoss()

# %%
# 训练参数
num_epochs = 100
# 训练循环
for epoch in range(num_epochs):
    
    for data, m in trainLoader:
            
        x_hat = generator(torch.cat([data, 1-m], dim=1))
        
        x_imputed = data + m * x_hat
        
        torch.autograd.set_detect_anomaly(True)
        
        #表示输入数据被判别为真实数据的概率
        D_output = discriminator(x_imputed)
        
        # 计算判别器的损失
        discriminator_loss = loss_function(D_output, 1-m)

        torch.nn.utils.clip_grad_norm_(generator.parameters(), max_norm=1)
        torch.nn.utils.clip_grad_norm_(discriminator.parameters(), max_norm=1)

        # 更新判别器
        dis_optimizer.zero_grad()
        discriminator_loss.backward(retain_graph=True)
        dis_optimizer.step()

        # 计算生成损失
        G_loss_temp = -torch.mean( m * torch.log(D_output + 1e-8))
        med_original_data = data * (1 - m)
        med_generated_data = x_hat * (1 - m)
        Mse_loss = mse_loss(med_generated_data, med_original_data)

        generator_loss = Mse_loss * 100 + G_loss_temp

        # 更新生成器
        gen_optimizer.zero_grad()
        generator_loss.backward(retain_graph=True)
        gen_optimizer.step()

    # 打印每个epoch的损失
    print(f"Epoch [{epoch+1}/{num_epochs}] | Generator Loss: {generator_loss.item()} | Discriminator Loss: {discriminator_loss.item()}")
    torch.save(generator,r'./model/allen_{}.pth'.format(epoch + 1))
# Out:
# D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\autograd\__init__.py:200: UserWarning: Error detected in AddmmBackward0. Traceback of forward call that caused the error:
#   File "D:\AnacondaEnv\envs\pytorch02\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "D:\AnacondaEnv\envs\pytorch02\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_8356\2445332786.py", line 15, in <module>
#     D_output = discriminator(x_imputed)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\nn\modules\module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_8356\1898537176.py", line 26, in forward
#     validity = torch.sigmoid(self.fc3(x))
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\nn\modules\module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\nn\modules\linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
#  (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\autograd\python_anomaly_mode.cpp:119.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 38
#      36     # 更新生成器
#      37     gen_optimizer.zero_grad()
# ---> 38     generator_loss.backward(retain_graph=True)
#      39     gen_optimizer.step()
#      41 # 打印每个epoch的损失
#
# File D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File D:\AnacondaEnv\envs\pytorch02\lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.FloatTensor [64, 7]], which is output 0 of AsStridedBackward0, is at version 5; expected version 4 instead. Hint: the backtrace further above shows the operation that failed to compute its gradient. The variable in question was changed in there or anywhere later. Good luck!
