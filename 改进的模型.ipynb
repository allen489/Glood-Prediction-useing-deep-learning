# %%
import pandas as pd
import numpy as np
data_path = r"E:\pythonProject\JupyterFile\jupyter_File\Aleppo (2017)\Aleppo2017_processed.csv"
df = pd.read_csv(data_path, encoding='utf-8')
ID = df['id'].value_counts().index
data = df[df['id'] == ID[0]][:1000]
data = data.sort_values(by='time')
# 时间为行索引
data.index = data['time']

# 设置标签
data['target'] = data['gl'].shift(-1)
data.dropna()  # 使用了shift函数，在最后必然是有缺失值的，这里去掉缺失值所在行
data = data[['gl', 'target']].astype(np.float32)  # 修改数据类型

# %%
seq = 12
data_windows = []
targets = []
for index in range(len(data) - seq):
    # 构建特征集
    data_windows.append(data['gl'][index: index + seq].values)
    # 构建target集
    targets.append(data['target'].iloc[index + seq])

# %%
import torch
data_windows = np.array(data_windows)
data_windows = torch.tensor(data_windows)
data_windows = data_windows.unsqueeze(-1)
data_windows.shape
# Out:
# torch.Size([988, 12, 1])

# %%
targets = np.array(targets)
targets = torch.tensor(targets)
targets.shape
# Out:
# torch.Size([988])

# %%
from torch import nn as nn
import torch
Device = torch.device("cuda:0")
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=1):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        c0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
# 初始化模型
input_size = 1  # 因为我们只使用了血糖值作为输入特征
hidden_size = 32
num_layers = 2
model = LSTMModel(input_size, hidden_size, num_layers)
model = model.to(Device)

# %%
# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = criterion.to(Device)

# %%
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    data_windows = data_windows.to(Device)
    targets = targets.to(Device)
    outputs = model(data_windows)
    print(data_windowsw)
    print("outputs: ",outputs)    
#     print("targets.shape",targets.shape)
    loss = criterion(outputs.squeeze(-1), targets)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# outputs:  tensor([[nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
#         [nan],
# ...

# %%
data_windows[0,:,:].shape
x = data_windows[0,:,:].unsqueeze(0)
print(model(x))
# Out:
# tensor([[nan]], device='cuda:0', grad_fn=<AddmmBackward0>)
